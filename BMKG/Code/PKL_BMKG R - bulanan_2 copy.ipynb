# %% [markdown]
# ### **Analisis Hubungan Curah Hujan dan Kecepatan Angin terhadap Variasi Temperatur Rata-rata di Wilayah Tangerang, Kawasan Bandara Soekarno-Hatta**
#
# ---
#
# #### **Latar Belakang**
# Kawasan Bandara Soekarno-Hatta di Tangerang memiliki karakteristik cuaca yang unik, di mana variabilitas curah hujan, kecepatan angin, dan suhu dapat berdampak signifikan pada operasi penerbangan, termasuk keberangkatan, pendaratan, serta keselamatan penerbangan. Variasi temperatur rata-rata dapat memengaruhi kondisi atmosfer lokal, yang memengaruhi densitas udara dan performa pesawat. Dengan demikian, penting untuk memahami bagaimana curah hujan dan kecepatan angin memengaruhi variasi temperatur rata-rata di kawasan ini.
#
# Penelitian ini diharapkan dapat memberikan kontribusi pada prakiraan cuaca mikro di sekitar bandara, mitigasi dampak perubahan iklim, serta membantu meminimalisir potensi kecelakaan penerbangan akibat kondisi cuaca ekstrem.
#
# ---
#
# #### **Tujuan Penelitian**
# 1. Menganalisis pengaruh curah hujan terhadap variasi temperatur rata-rata di kawasan Bandara Soekarno-Hatta.
# 2. Menilai kontribusi kecepatan angin maksimum dan rata-rata terhadap perubahan temperatur rata-rata.
# 3. Memberikan rekomendasi terkait mitigasi risiko operasional di bandara berdasarkan analisis hubungan variabel cuaca.
#
# ---
#
# #### **Variabel yang Digunakan**
# 1. **Curah hujan (RR):** Menunjukkan intensitas curah hujan yang memengaruhi pendinginan atmosfer.
# 2. **Kecepatan angin maksimum (ff_x):** Menggambarkan kecepatan angin tertinggi yang berpotensi memengaruhi sirkulasi udara lokal.
# 3. **Kecepatan angin rata-rata (ff_avg):** Menunjukkan pola pergerakan angin yang memengaruhi distribusi suhu di kawasan bandara.
# 4. **Temperatur rata-rata (Tavg):** Merupakan parameter utama untuk mengukur kondisi termal harian di kawasan tersebut.
#
# ---
#
# #### **Metodologi Penelitian**
# 1. **Pengumpulan Data**:
#    - Data meteorologi (RR, ff_x, ff_avg, Tavg) dari stasiun BMKG di Bandara Soekarno-Hatta selama periode tertentu (misalnya 5 tahun terakhir).
#
# 2. **Pembersihan Data**:
#    - Menghilangkan nilai outlier dan data kosong untuk memastikan kualitas analisis.
#
# 3. **Analisis Statistik**:
#    - **Korelasi Pearson/Spearman** untuk mengevaluasi hubungan antara curah hujan, kecepatan angin, dan temperatur rata-rata.
#    - **Regresi Linear Berganda** untuk memodelkan pengaruh variabel independen (RR, ff_x, ff_avg) terhadap variabel dependen (Tavg).
#
# 4. **Visualisasi Data**:
#    - Membuat grafik scatter plot untuk menggambarkan hubungan antarvariabel.
#    - Heatmap untuk menunjukkan kekuatan korelasi antarvariabel.
#    - Tren temporal untuk melihat perubahan parameter cuaca secara berkala.
#
# ---
#
# #### **Hasil yang Diharapkan**
# 1. **Hubungan Kuantitatif Antarvariabel:**
#    - Mengidentifikasi seberapa besar curah hujan dan kecepatan angin berkontribusi terhadap perubahan temperatur rata-rata.
#
# 2. **Model Prediktif:**
#    - Menghasilkan model regresi untuk memprediksi temperatur rata-rata berdasarkan curah hujan dan kecepatan angin.
#
# 3. **Rekomendasi Operasional:**
#    - Strategi mitigasi risiko cuaca untuk operasional bandara, seperti pengaturan jadwal penerbangan pada kondisi cuaca tertentu.
#
# ---
#
# #### **Manfaat Penelitian**
# 1. **Bagi Bandara dan Operator Penerbangan:**
#    - Memberikan dasar ilmiah untuk menyesuaikan operasional berdasarkan kondisi cuaca mikro.
#
# 2. **Bagi BMKG:**
#    - Menambah wawasan tentang pola cuaca lokal di kawasan bandara untuk mendukung prakiraan cuaca yang lebih akurat.
#
# 3. **Bagi Peneliti:**
#    - Menyediakan informasi tambahan tentang hubungan variabel cuaca yang relevan untuk penelitian lebih lanjut dalam mitigasi dampak perubahan iklim.

# %% [markdown]
# # Import Dataset

# %%
data <- read.csv("C:/Users/Alif/OneDrive - uinjkt.ac.id/Kuliah UIN/PKL/BMKG/Data Iklim csv - Data Only/data_bulanan_2.csv")

# %%
head(data, 25)
# Out:
#    BULAN   TN   TX   TAVG     RH_AVG   RR         SS       FF_X DDD_X FF_AVG
# 1  2020-01 23.6 32.6 27.45806 83.90323 18.0784011 4.138710  8   300   2.290323
# 2  2020-02 22.6 34.0 27.12414 84.58621 21.9799252 3.924138  8   300   2.241379
# 3  2020-03 22.2 34.5 27.70968 82.35484  7.4925403 5.177419  9   330   2.129032
# 4  2020-04 23.8 34.4 28.23667 80.80000  2.1374194 6.053333  7    30   2.166667
# 5  2020-05 23.4 35.0 28.34516 80.61290  3.2741935 5.774194  9    60   2.451613
# 6  2020-06 23.4 33.8 28.05517 78.20690  0.6343236 5.937931  8    60   2.310345
# 7  2020-07 21.6 33.7 27.60323 76.09677  1.1049088 6.277419  8    60   2.322581
# 8  2020-08 20.8 34.2 27.62581 76.06452  5.7499151 7.348387 10    50   2.612903
# 9  2020-09 22.0 33.8 28.11667 73.50000  4.2077971 6.836667 18    40   2.366667
# 10 2020-10 22.0 33.6 28.03871 77.22581  4.0824504 6.025806  8    60   2.322581
# 11 2020-11 22.6 34.9 28.31667 76.10000  1.5073810 5.533333 11    40   2.833333
# ...

# %%
str(data)
# Out:
# 'data.frame':	60 obs. of  11 variables:
#  $ BULAN  : chr  "2020-01" "2020-02" "2020-03" "2020-04" ...
#  $ TN     : num  23.6 22.6 22.2 23.8 23.4 23.4 21.6 20.8 22 22 ...
#  $ TX     : num  32.6 34 34.5 34.4 35 33.8 33.7 34.2 33.8 33.6 ...
#  $ TAVG   : num  27.5 27.1 27.7 28.2 28.3 ...
#  $ RH_AVG : num  83.9 84.6 82.4 80.8 80.6 ...
#  $ RR     : num  18.08 21.98 7.49 2.14 3.27 ...
#  $ SS     : num  4.14 3.92 5.18 6.05 5.77 ...
#  $ FF_X   : num  8 8 9 7 9 8 8 10 18 8 ...
#  $ DDD_X  : num  300 300 330 30 60 60 60 50 40 60 ...
#  $ FF_AVG : num  2.29 2.24 2.13 2.17 2.45 ...
#  $ DDD_CAR: chr  "N" "NW" "S" "S" ...

# %%
unique(data$DDD_CAR)
# Out:
# [1] "N"  "NW" "S"  "E"  "NE" "SW" "W"

# %%
# install.packages("fastDummies")

# %%
# Load paket fastDummies
library(fastDummies)

# Membuat dummy hanya untuk kolom DDD_CAR
data <- dummy_cols(data, select_columns = "DDD_CAR", remove_selected_columns = TRUE)

# Melihat hasil
head(data)
# Out:
# Warning message:
# "package 'fastDummies' was built under R version 4.4.2"
#   BULAN   TN   TX   TAVG     RH_AVG   RR         SS       FF_X DDD_X FF_AVG
# 1 2020-01 23.6 32.6 27.45806 83.90323 18.0784011 4.138710 8    300   2.290323
# 2 2020-02 22.6 34.0 27.12414 84.58621 21.9799252 3.924138 8    300   2.241379
# 3 2020-03 22.2 34.5 27.70968 82.35484  7.4925403 5.177419 9    330   2.129032
# 4 2020-04 23.8 34.4 28.23667 80.80000  2.1374194 6.053333 7     30   2.166667
# 5 2020-05 23.4 35.0 28.34516 80.61290  3.2741935 5.774194 9     60   2.451613
# 6 2020-06 23.4 33.8 28.05517 78.20690  0.6343236 5.937931 8     60   2.310345
#   DDD_CAR_E DDD_CAR_N DDD_CAR_NE DDD_CAR_NW DDD_CAR_S DDD_CAR_SW DDD_CAR_W
# 1 0         1         0          0          0         0          0
# 2 0         0         0          1          0         0          0
# 3 0         0         0          0          1         0          0
# 4 0         0         0          0          1         0          0
# ...

# %% [markdown]
# 1. N - North (Utara)
# 2. S - South (Selatan)
# 3. E - East (Timur)
# 4. W - West (Barat)
# 5. NE - Northeast (Timur Laut)
# 6. NW - Northwest (Barat Laut)
# 7. SE - Southeast (Tenggara)
# 8. SW - Southwest (Barat Daya)

# %%
head(data)
# Out:
#   BULAN   TN   TX   TAVG     RH_AVG   RR         SS       FF_X DDD_X FF_AVG
# 1 2020-01 23.6 32.6 27.45806 83.90323 18.0784011 4.138710 8    300   2.290323
# 2 2020-02 22.6 34.0 27.12414 84.58621 21.9799252 3.924138 8    300   2.241379
# 3 2020-03 22.2 34.5 27.70968 82.35484  7.4925403 5.177419 9    330   2.129032
# 4 2020-04 23.8 34.4 28.23667 80.80000  2.1374194 6.053333 7     30   2.166667
# 5 2020-05 23.4 35.0 28.34516 80.61290  3.2741935 5.774194 9     60   2.451613
# 6 2020-06 23.4 33.8 28.05517 78.20690  0.6343236 5.937931 8     60   2.310345
#   DDD_CAR_E DDD_CAR_N DDD_CAR_NE DDD_CAR_NW DDD_CAR_S DDD_CAR_SW DDD_CAR_W
# 1 0         1         0          0          0         0          0
# 2 0         0         0          1          0         0          0
# 3 0         0         0          0          1         0          0
# 4 0         0         0          0          1         0          0
# 5 1         0         0          0          0         0          0
# ...

# %%
# Membangun model regresi linear berganda
model <- lm(TAVG ~ TN + TX + RH_AVG + RR + SS + FF_X + DDD_CAR_N + DDD_CAR_NE + DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W, data = data)

# Melihat ringkasan model
summary(model)
# Out:
# Call:
# lm(formula = TAVG ~ TN + TX + RH_AVG + RR + SS + FF_X + DDD_CAR_N +
#     DDD_CAR_NE + DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W,
#     data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.80068 -0.14653 -0.00823  0.15349  0.54556
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept) 14.583780   3.494259   4.174 0.000128 ***
# TN           0.359274   0.041810   8.593 3.37e-11 ***
# TX           0.236758   0.075352   3.142 0.002902 **
# RH_AVG      -0.042571   0.018899  -2.253 0.029000 *
# RR          -0.010530   0.014558  -0.723 0.473100
# SS           0.135633   0.054834   2.474 0.017049 *
# FF_X        -0.032429   0.019831  -1.635 0.108666
# DDD_CAR_N   -0.004849   0.273521  -0.018 0.985931
# DDD_CAR_NE   0.403702   0.156503   2.580 0.013082 *
# DDD_CAR_NW   0.036770   0.270009   0.136 0.892259
# DDD_CAR_S    0.105700   0.135197   0.782 0.438239
# DDD_CAR_SW   0.137873   0.145562   0.947 0.348394
# ...

# %%
library(car)
# Menampilkan hasil VIF dalam format data frame
vif_df <- data.frame(VIF = vif(model))
print(vif_df)
# Out:
# Warning message:
# "package 'car' was built under R version 4.4.2"
# Loading required package: carData
#                 VIF
# TN         1.262366
# TX         2.170203
# RH_AVG     3.292996
# RR         3.527445
# SS         3.972104
# FF_X       1.152605
# DDD_CAR_N  1.776719
# DDD_CAR_NE 1.860370
# DDD_CAR_NW 2.552296
# DDD_CAR_S  2.286411
# DDD_CAR_SW 3.470288
# DDD_CAR_W  2.435949

# %% [markdown]
# # stepwise

# %%
model.step <- step(model, direction = "both", trace = TRUE)
# Out:
# Start:  AIC=-139.15
# TAVG ~ TN + TX + RH_AVG + RR + SS + FF_X + DDD_CAR_N + DDD_CAR_NE +
#     DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W
#
#              Df Sum of Sq    RSS      AIC
# - DDD_CAR_N   1    0.0000 3.8262 -141.148
# - DDD_CAR_NW  1    0.0015 3.8277 -141.125
# - DDD_CAR_W   1    0.0255 3.8517 -140.749
# - RR          1    0.0426 3.8688 -140.484
# - DDD_CAR_S   1    0.0498 3.8760 -140.373
# - DDD_CAR_SW  1    0.0730 3.8992 -140.014
# <none>                    3.8262 -139.148
# - FF_X        1    0.2177 4.0439 -137.828
# - RH_AVG      1    0.4130 4.2392 -134.998
# - SS          1    0.4981 4.3243 -133.806
# - DDD_CAR_NE  1    0.5417 4.3679 -133.204
# - TX          1    0.8037 4.6299 -129.709
# - TN          1    6.0113 9.8375  -84.489
#
# Step:  AIC=-141.15
# TAVG ~ TN + TX + RH_AVG + RR + SS + FF_X + DDD_CAR_NE + DDD_CAR_NW +
#     DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W
#
#              Df Sum of Sq    RSS      AIC
# - DDD_CAR_NW  1    0.0021 3.8283 -143.115
# ...

# %%
model2 <- lm(TAVG ~ TN + TX + RH_AVG + SS + FF_X + DDD_CAR_NE, data = data)
summary(model2)
# Out:
# Call:
# lm(formula = TAVG ~ TN + TX + RH_AVG + SS + FF_X + DDD_CAR_NE,
#     data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.7973 -0.1797 -0.0108  0.1641  0.5489
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 15.33901    3.20119   4.792 1.38e-05 ***
# TN           0.35508    0.03776   9.405 6.88e-13 ***
# TX           0.24488    0.06192   3.954 0.000229 ***
# RH_AVG      -0.05357    0.01659  -3.229 0.002134 **
# SS           0.12866    0.03879   3.317 0.001649 **
# FF_X        -0.03360    0.01868  -1.798 0.077823 .
# DDD_CAR_NE   0.32772    0.12910   2.539 0.014104 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2769 on 53 degrees of freedom
# Multiple R-squared:  0.8113,	Adjusted R-squared:  0.7899
# F-statistic: 37.98 on 6 and 53 DF,  p-value: < 2.2e-16

# %% [markdown]
# ## Analisis residual
#
# Setelah mendapatkan model terbaik dengan melakukan pemilihan model menggunakan stepwise, selanjutnya akan dilakukan analisis residual untuk melihat apakah model regresi yang dipilih memenuhi asumsi-asumsi dari regresi linear atau tidak.

# %% [markdown]
# ### Asumsi normalitas
#
# Melihat histogram dan qqplot

# %%
install.packages("olsrr")
# Out:
# Installing package into 'C:/Users/Alif/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'olsrr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Alif\AppData\Local\Temp\RtmpkdCabt\downloaded_packages

# %%
library(olsrr)
resid1 <- residuals(model2)
resid2 <- rstandard(model2)
hist(resid2, xlab = "residual", main = "")
ols_plot_resid_qq(model2)
# Out:
# Warning message:
# "package 'olsrr' was built under R version 4.4.2"
#
# Attaching package: 'olsrr'
#
#
# The following object is masked from 'package:datasets':
#
#     rivers
# Plot with title ""
# plot without title

# %% [markdown]
# Uji hipotesis normalitas:
#
# -   H0: residual mengikuti distribusi normal
#
# -   H1: residual tidak mengikuti distribusi normal

# %%
ols_test_normality(model2)
# Out:
# -----------------------------------------------
#        Test             Statistic       pvalue
# -----------------------------------------------
# Shapiro-Wilk              0.9869         0.7678
# Kolmogorov-Smirnov        0.0654         0.9446
# Cramer-von Mises         11.5491         0.0000
# Anderson-Darling          0.2029         0.8717
# -----------------------------------------------

# %% [markdown]
# ### Asumsi Homoskedastisitas

# %%
ols_plot_resid_fit(model2)
plot(fitted(model2), rstandard(model2))
# Out:
# plot without title
# plot without title

# %% [markdown]
# **uji Breusch-Pagan**
#
# Uji hipotesis variansi konstan:
#
# -   H0: variansi residual konstan (homoskedastisitas)
#
# -   H1: variansi residual tidak konstan (heteroskedastisitas)

# %%
# Install and load the lmtest package
# install.packages("lmtest")
library(lmtest)

# Perform the Breusch-Pagan test
bptest(model2)
# Out:
# Warning message:
# "package 'lmtest' was built under R version 4.4.1"
# Loading required package: zoo
# Warning message:
# "package 'zoo' was built under R version 4.4.1"
#
# Attaching package: 'zoo'
#
#
# The following objects are masked from 'package:base':
#
#     as.Date, as.Date.numeric
# 	studentized Breusch-Pagan test
#
# data:  model2
# BP = 8.3662, df = 6, p-value = 0.2125

# %% [markdown]
# ### Asumsi Independen
#
# **Dengan uji Durbin-Watson**
#
# Uji hipotesis variansi konstan:
#
# -   H0: residual independent
#
# -   H1: residual tidak independent

# %%
durbinWatsonTest(model2)
# Out:
#  lag Autocorrelation D-W Statistic p-value
#    1       0.3453988      1.309078   0.002
#  Alternative hypothesis: rho != 0

# %%
# Load package yang diperlukan
library(forecast)

# Misalkan residual dari model regresi disimpan dalam variabel residuals_model
residuals_model <- residuals(model2)  # Sesuaikan dengan nama model regresi kamu

# Plot ACF dan PACF
par(mfrow = c(1, 2))  # Membagi tampilan menjadi 2 kolom
acf(residuals_model, main = "Autocorrelation Function (ACF)")
pacf(residuals_model, main = "Partial Autocorrelation Function (PACF)")
# Out:
# Warning message:
# "package 'forecast' was built under R version 4.4.2"
# Registered S3 method overwritten by 'quantmod':
#   method            from
#   as.zoo.data.frame zoo
# Plot with title "Partial Autocorrelation Function (PACF)"

# %%
dwtest(model2)
# Out:
# 	Durbin-Watson test
#
# data:  model2
# DW = 1.3091, p-value = 0.00136
# alternative hypothesis: true autocorrelation is greater than 0

# %% [markdown]
# **Dengan Uji Breusch-Godfrey**

# %%
# Uji Breusch-Godfrey
bg_test <- bgtest(model2, order = 11)  # Order = jumlah lag yang diuji
print(bg_test)
# Out:
# 	Breusch-Godfrey test for serial correlation of order up to 11
#
# data:  model2
# LM test = 18.843, df = 11, p-value = 0.06398

# %% [markdown]
# ### **Penjelasan Konsep Lag dalam Permasalahan Uji Breusch-Godfrey**
#
# Dalam analisis model regresi yang dilakukan, uji Breusch-Godfrey digunakan untuk memeriksa **autokorelasi residual**, yaitu hubungan antara residual saat ini (\(e_t\)) dengan residual pada periode sebelumnya (\(e_{t-1}, e_{t-2}, \dots\)). Konsep **lag** dalam konteks ini mengacu pada "periode keterkaitan" residual dalam data.
#
# Misalnya:
# - **Lag 1 (\(e_{t-1}\))**: Residual saat ini (\(e_t\)) dibandingkan dengan residual satu periode sebelumnya.
# - **Lag 2 (\(e_{t-2}\))**: Residual saat ini (\(e_t\)) dibandingkan dengan residual dua periode sebelumnya.
# - **Lag 3 (\(e_{t-3}\))**: Residual saat ini (\(e_t\)) dibandingkan dengan residual tiga periode sebelumnya.
#
# Dalam uji yang dilakukan, Breusch-Godfrey menguji keberadaan autokorelasi residual **hingga lag ke-3**.
#
# ---
#
# ### **Hasil Uji Breusch-Godfrey**
#
# Berikut adalah hasil uji Breusch-Godfrey:
# ```
# Breusch-Godfrey test for serial correlation of order up to 3
#
# data:  model3
# LM test = 6.7078, df = 3, p-value = 0.08182
# ```
#
# **Penjelasan:**
# 1. **LM Test**: Statistik uji sebesar **6.7078** menunjukkan tingkat autokorelasi yang dihitung berdasarkan hubungan residual hingga lag ke-3.
# 2. **df (Derajat Kebebasan)**: Derajat kebebasan sebesar **3** karena uji dilakukan hingga lag ke-3.
# 3. **p-value**: Nilai **p-value = 0.08182** menunjukkan probabilitas hasil uji ini terjadi jika hipotesis nol (\(H_0\)) benar.
#
# ---
#
# ### **Interpretasi**
#
# 1. **Hipotesis Uji Breusch-Godfrey**:
#    - **Hipotesis Nol (\(H_0\))**: Tidak ada autokorelasi residual hingga lag ke-3.
#    - **Hipotesis Alternatif (\(H_a\))**: Ada autokorelasi residual hingga lag ke-3.
#
# 2. **Hasil Uji**:
#    - Karena **p-value = 0.08182 > 0.05**, maka **gagal menolak hipotesis nol (\(H_0\))**.
#    - Ini berarti **tidak ada bukti statistik yang cukup untuk menyimpulkan adanya autokorelasi residual** hingga lag ke-3.
#
# 3. **Kesimpulan Praktis**:
#    - Residual dari model **independen** hingga lag ke-3, sehingga asumsi independensi residual dalam model ini terpenuhi.
#
# ---
#
# ### **Relevansi Lag dalam Permasalahan**
#
# Dalam analisis model:
# - Uji Breusch-Godfrey menguji autokorelasi residual untuk memastikan bahwa residual pada waktu \(t\) **tidak dipengaruhi** oleh residual pada waktu sebelumnya (\(t-1, t-2, \dots\)).
# - Hasil menunjukkan bahwa **tidak ada autokorelasi signifikan** hingga lag ke-3, sehingga model valid dari sisi asumsi independensi residual.

# %% [markdown]
# ### Uji global dan parsial

# %%
summary(model2)
# Out:
# Call:
# lm(formula = TAVG ~ TN + TX + RH_AVG + SS + FF_X + DDD_CAR_NE,
#     data = data)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -0.7973 -0.1797 -0.0108  0.1641  0.5489
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 15.33901    3.20119   4.792 1.38e-05 ***
# TN           0.35508    0.03776   9.405 6.88e-13 ***
# TX           0.24488    0.06192   3.954 0.000229 ***
# RH_AVG      -0.05357    0.01659  -3.229 0.002134 **
# SS           0.12866    0.03879   3.317 0.001649 **
# FF_X        -0.03360    0.01868  -1.798 0.077823 .
# DDD_CAR_NE   0.32772    0.12910   2.539 0.014104 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2769 on 53 degrees of freedom
# Multiple R-squared:  0.8113,	Adjusted R-squared:  0.7899
# F-statistic: 37.98 on 6 and 53 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### Model baru lagi

# %%
model3 <- lm(TAVG ~ TN + TX + RH_AVG + SS + DDD_CAR_NE, data = data)
summary(model3)
# Out:
# Call:
# lm(formula = TAVG ~ TN + TX + RH_AVG + SS + DDD_CAR_NE, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.72632 -0.18493 -0.01715  0.14640  0.56805
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 15.37298    3.26667   4.706 1.80e-05 ***
# TN           0.34497    0.03810   9.054 2.04e-12 ***
# TX           0.24312    0.06318   3.848 0.000317 ***
# RH_AVG      -0.05382    0.01693  -3.179 0.002447 **
# SS           0.12515    0.03953   3.166 0.002543 **
# DDD_CAR_NE   0.27634    0.12847   2.151 0.035971 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2826 on 54 degrees of freedom
# Multiple R-squared:  0.7998,	Adjusted R-squared:  0.7812
# F-statistic: 43.14 on 5 and 54 DF,  p-value: < 2.2e-16

# %% [markdown]
# ### Asumsi Normalitas 2

# %%
library(olsrr)
resid1 <- residuals(model3)
resid2 <- rstandard(model3)
hist(resid2, xlab = "residual", main = "")
ols_plot_resid_qq(model3)
# Out:
# Plot with title ""
# plot without title

# %%
ols_test_normality(model3)
# Out:
# -----------------------------------------------
#        Test             Statistic       pvalue
# -----------------------------------------------
# Shapiro-Wilk              0.9863         0.7370
# Kolmogorov-Smirnov        0.058          0.9806
# Cramer-von Mises         11.2453         0.0000
# Anderson-Darling          0.2642         0.6858
# -----------------------------------------------

# %% [markdown]
# ### Asumsi homoskedastisitas 2

# %%
ols_plot_resid_fit(model3)
plot(fitted(model3), rstandard(model3))
# Out:
# plot without title
# plot without title

# %%
# Install and load the lmtest package
# install.packages("lmtest")
library(lmtest)

# Perform the Breusch-Pagan test
bptest(model3)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  model3
# BP = 5.7974, df = 5, p-value = 0.3264

# %% [markdown]
# ### Asumsi Independen 2

# %%
durbinWatsonTest(model3)
# Out:
#  lag Autocorrelation D-W Statistic p-value
#    1       0.3097604      1.380207   0.008
#  Alternative hypothesis: rho != 0

# %%
# Load package yang diperlukan
library(forecast)

# Misalkan residual dari model regresi disimpan dalam variabel residuals_model
residuals_model <- residuals(model3)  # Sesuaikan dengan nama model regresi kamu

# Plot ACF dan PACF
par(mfrow = c(1, 2))  # Membagi tampilan menjadi 2 kolom
acf(residuals_model, main = "Autocorrelation Function (ACF)")
pacf(residuals_model, main = "Partial Autocorrelation Function (PACF)")
# Out:
# Plot with title "Partial Autocorrelation Function (PACF)"

# %%
# Uji Breusch-Godfrey
bg_test <- bgtest(model3, order = 3)  # Order = jumlah lag yang diuji
print(bg_test)
# Out:
# 	Breusch-Godfrey test for serial correlation of order up to 3
#
# data:  model3
# LM test = 7.0827, df = 3, p-value = 0.06931

# %%
summary(model3)
# Out:
# Call:
# lm(formula = TAVG ~ TN + TX + RH_AVG + SS + DDD_CAR_NE, data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.72632 -0.18493 -0.01715  0.14640  0.56805
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 15.37298    3.26667   4.706 1.80e-05 ***
# TN           0.34497    0.03810   9.054 2.04e-12 ***
# TX           0.24312    0.06318   3.848 0.000317 ***
# RH_AVG      -0.05382    0.01693  -3.179 0.002447 **
# SS           0.12515    0.03953   3.166 0.002543 **
# DDD_CAR_NE   0.27634    0.12847   2.151 0.035971 *
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2826 on 54 degrees of freedom
# Multiple R-squared:  0.7998,	Adjusted R-squared:  0.7812
# F-statistic: 43.14 on 5 and 54 DF,  p-value: < 2.2e-16

# %% [markdown]
# ========================================================================================================================================================

# %% [markdown]
# # Model Dengan Interaksi

# %% [markdown]
# 1. Tn (Temperatur Minimum) dan Tx (Temperatur Maksimum)
#
#     Interaksi: Suhu minimum dan maksimum bisa saling mempengaruhi. Perbedaan besar antara suhu maksimum dan minimum dapat memberikan informasi tentang fluktuasi suhu harian yang bisa memengaruhi suhu rata-rata (Tavg).
#
# 2. Tn (Temperatur Minimum) dan RH_avg (Kelembapan Rata-rata)
#
#     Interaksi: Kelembapan yang tinggi dapat mempengaruhi pengurangan penurunan suhu pada malam hari. Interaksi ini mungkin berhubungan dengan pengaruh kelembapan terhadap suhu malam hari dan bagaimana hal ini mempengaruhi suhu rata-rata.
#
# 3. Tx (Temperatur Maksimum) dan ss (Lamanya Penyinaran Matahari)
#
#     Interaksi: Lamanya penyinaran matahari berhubungan langsung dengan suhu maksimum yang tercatat. Interaksi antara keduanya sangat relevan, karena durasi penyinaran matahari dapat memengaruhi suhu maksimum dan pada gilirannya berpotensi mempengaruhi Tavg.
#
# 4. ff_avg (Kecepatan Angin Rata-rata) dan ff_x (Kecepatan Angin Maksimum)
#
#     Interaksi: Angin yang lebih kuat dapat mengubah distribusi suhu dan mempengaruhi suhu rata-rata dengan cara mengurangi efek pemanasan di atmosfer atau mempercepat pendinginan.
#
# 5. RH_avg (Kelembapan Rata-rata) dan RR (Curah Hujan)
#
#     Interaksi: Curah hujan dan kelembapan seringkali berkorelasi tinggi. Curah hujan tinggi sering kali terjadi ketika kelembapan relatif tinggi, yang bisa menurunkan suhu sekitar (efek pendinginan) dan mempengaruhi suhu rata-rata.
#
# 6. ff_avg (Kecepatan Angin Rata-rata) dan ddd_car (Arah Angin Terbanyak)
#
#     Interaksi: Arah angin dapat mempengaruhi suhu di wilayah tersebut. Interaksi antara kecepatan angin rata-rata dan arah angin bisa mempengaruhi bagaimana angin mendistribusikan suhu di area tertentu.

# %%
modelint <- lm(TAVG ~ TN + TX + RH_AVG + SS + FF_AVG + TX*SS, data = data)
summary(modelint)
# Out:
# Call:
# lm(formula = TAVG ~ TN + TX + RH_AVG + SS + FF_AVG + TX * SS,
#     data = data)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -0.64299 -0.15989 -0.00706  0.18116  0.60165
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept) 10.04408    6.40867   1.567  0.12300
# TN           0.34740    0.03681   9.439 6.10e-13 ***
# TX           0.49433    0.18192   2.717  0.00887 **
# RH_AVG      -0.07870    0.01654  -4.758 1.55e-05 ***
# SS           1.97449    1.06097   1.861  0.06829 .
# FF_AVG      -0.44073    0.15363  -2.869  0.00591 **
# TX:SS       -0.05564    0.03122  -1.782  0.08040 .
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 0.2723 on 53 degrees of freedom
# Multiple R-squared:  0.8175,	Adjusted R-squared:  0.7969
# F-statistic: 39.58 on 6 and 53 DF,  p-value: < 2.2e-16

# %%
model.step <- step(modelint, direction = "backward", trace = TRUE)
# Out:
# Start:  AIC=-149.56
# TAVG ~ TN + TX + RH_AVG + SS + FF_AVG + TX * SS
#
#          Df Sum of Sq     RSS     AIC
# <none>                 3.9289 -149.56
# - TX:SS   1    0.2355  4.1644 -148.07
# - FF_AVG  1    0.6101  4.5389 -142.90
# - RH_AVG  1    1.6781  5.6070 -130.22
# - TN      1    6.6041 10.5330  -92.39
