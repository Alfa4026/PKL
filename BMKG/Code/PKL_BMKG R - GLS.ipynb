# %% [markdown]
# ### **Analisis Hubungan Curah Hujan dan Kecepatan Angin terhadap Variasi Temperatur Rata-rata di Wilayah Tangerang, Kawasan Bandara Soekarno-Hatta**
#
# ---
#
# #### **Latar Belakang**
# Kawasan Bandara Soekarno-Hatta di Tangerang memiliki karakteristik cuaca yang unik, di mana variabilitas curah hujan, kecepatan angin, dan suhu dapat berdampak signifikan pada operasi penerbangan, termasuk keberangkatan, pendaratan, serta keselamatan penerbangan. Variasi temperatur rata-rata dapat memengaruhi kondisi atmosfer lokal, yang memengaruhi densitas udara dan performa pesawat. Dengan demikian, penting untuk memahami bagaimana curah hujan dan kecepatan angin memengaruhi variasi temperatur rata-rata di kawasan ini.
#
# Penelitian ini diharapkan dapat memberikan kontribusi pada prakiraan cuaca mikro di sekitar bandara, mitigasi dampak perubahan iklim, serta membantu meminimalisir potensi kecelakaan penerbangan akibat kondisi cuaca ekstrem.
#
# ---
#
# #### **Tujuan Penelitian**
# 1. Menganalisis pengaruh curah hujan terhadap variasi temperatur rata-rata di kawasan Bandara Soekarno-Hatta.
# 2. Menilai kontribusi kecepatan angin maksimum dan rata-rata terhadap perubahan temperatur rata-rata.
# 3. Memberikan rekomendasi terkait mitigasi risiko operasional di bandara berdasarkan analisis hubungan variabel cuaca.
#
# ---
#
# #### **Variabel yang Digunakan**
# 1. **Curah hujan (RR):** Menunjukkan intensitas curah hujan yang memengaruhi pendinginan atmosfer.
# 2. **Kecepatan angin maksimum (ff_x):** Menggambarkan kecepatan angin tertinggi yang berpotensi memengaruhi sirkulasi udara lokal.
# 3. **Kecepatan angin rata-rata (ff_avg):** Menunjukkan pola pergerakan angin yang memengaruhi distribusi suhu di kawasan bandara.
# 4. **Temperatur rata-rata (Tavg):** Merupakan parameter utama untuk mengukur kondisi termal harian di kawasan tersebut.
#
# ---
#
# #### **Metodologi Penelitian**
# 1. **Pengumpulan Data**:
#    - Data meteorologi (RR, ff_x, ff_avg, Tavg) dari stasiun BMKG di Bandara Soekarno-Hatta selama periode tertentu (misalnya 5 tahun terakhir).
#
# 2. **Pembersihan Data**:
#    - Menghilangkan nilai outlier dan data kosong untuk memastikan kualitas analisis.
#
# 3. **Analisis Statistik**:
#    - **Korelasi Pearson/Spearman** untuk mengevaluasi hubungan antara curah hujan, kecepatan angin, dan temperatur rata-rata.
#    - **Regresi Linear Berganda** untuk memodelkan pengaruh variabel independen (RR, ff_x, ff_avg) terhadap variabel dependen (Tavg).
#
# 4. **Visualisasi Data**:
#    - Membuat grafik scatter plot untuk menggambarkan hubungan antarvariabel.
#    - Heatmap untuk menunjukkan kekuatan korelasi antarvariabel.
#    - Tren temporal untuk melihat perubahan parameter cuaca secara berkala.
#
# ---
#
# #### **Hasil yang Diharapkan**
# 1. **Hubungan Kuantitatif Antarvariabel:**
#    - Mengidentifikasi seberapa besar curah hujan dan kecepatan angin berkontribusi terhadap perubahan temperatur rata-rata.
#
# 2. **Model Prediktif:**
#    - Menghasilkan model regresi untuk memprediksi temperatur rata-rata berdasarkan curah hujan dan kecepatan angin.
#
# 3. **Rekomendasi Operasional:**
#    - Strategi mitigasi risiko cuaca untuk operasional bandara, seperti pengaturan jadwal penerbangan pada kondisi cuaca tertentu.
#
# ---
#
# #### **Manfaat Penelitian**
# 1. **Bagi Bandara dan Operator Penerbangan:**
#    - Memberikan dasar ilmiah untuk menyesuaikan operasional berdasarkan kondisi cuaca mikro.
#
# 2. **Bagi BMKG:**
#    - Menambah wawasan tentang pola cuaca lokal di kawasan bandara untuk mendukung prakiraan cuaca yang lebih akurat.
#
# 3. **Bagi Peneliti:**
#    - Menyediakan informasi tambahan tentang hubungan variabel cuaca yang relevan untuk penelitian lebih lanjut dalam mitigasi dampak perubahan iklim.

# %% [markdown]
# # Import Dataset

# %%
data <- read.csv("C:/Users/Alif/OneDrive - uinjkt.ac.id/Kuliah UIN/PKL/BMKG/Data Iklim csv - Data Only/data_cleaned.csv")

# %%
head(data, 25)
# Out:
#    TN   TX    TAVG RH_AVG RR        SS  FF_X DDD_X FF_AVG DDD_CAR
# 1  24.9 31.00 27.6 84      0.300000 4.8 5    290   2      W
# 2  25.8 31.10 28.2 80      9.200000 3.0 5    300   3      NW
# 3  25.7 29.50 27.0 88      4.500000 1.0 4    310   2      W
# 4  25.0 30.20 27.3 83      0.200000 2.7 6    320   2      W
# 5  25.6 29.60 28.0 82      7.100000 0.0 6    240   4      W
# 6  23.9 31.60 26.8 84     10.800000 0.0 8    240   3      SW
# 7  24.4 32.30 28.3 78      3.500000 5.4 6    310   3      W
# 8  25.5 30.20 27.1 87      1.000000 8.8 4    320   2      NW
# 9  24.7 31.80 28.3 79      6.300000 1.9 5    320   3      N
# 10 24.8 31.40 27.6 83      3.150000 6.0 6     10   2      S
# 11 24.9 31.70 28.0 83      0.000000 4.9 5    320   3      N
# 12 25.0 31.10 27.2 80      7.300000 7.2 3     30   2      N
# 13 23.6 31.80 27.7 84      0.000000 2.3 4    350   2      N
# 14 25.4 31.20 28.6 80      0.000000 9.8 5    350   2      N
# 15 25.0 30.60 27.5 84      3.600000 5.1 4    310   2      N
# 16 25.0 31.20 27.7 83      5.000000 6.8 4    310   2      N
# 17 25.2 30.20 26.2 93      5.500000 6.3 4    250   2      W
# 18 24.3 30.75 27.7 84      1.700000 1.0 5    360   2      N
# 19 24.9 31.30 27.9 83      4.900000 8.2 5     10   2      SW
# 20 25.0 32.00 28.3 82      3.266667 5.5 3    290   2      N
# 21 25.4 32.60 28.6 79      1.633333 8.0 6    300   2      N
# 22 24.0 29.60 27.7 84      0.000000 2.9 8    270   3      NE
# 23 24.0 29.60 25.8 92     11.400000 0.6 3     40   1      S
# 24 24.5 30.00 26.0 92      0.500000 0.0 3    340   2      NE
# 25 23.7 30.60 26.1 85      9.100000 6.5 5    300   2      W

# %%
str(data)
# Out:
# 'data.frame':	1507 obs. of  10 variables:
#  $ TN     : num  24.9 25.8 25.7 25 25.6 23.9 24.4 25.5 24.7 24.8 ...
#  $ TX     : num  31 31.1 29.5 30.2 29.6 31.6 32.3 30.2 31.8 31.4 ...
#  $ TAVG   : num  27.6 28.2 27 27.3 28 26.8 28.3 27.1 28.3 27.6 ...
#  $ RH_AVG : num  84 80 88 83 82 84 78 87 79 83 ...
#  $ RR     : num  0.3 9.2 4.5 0.2 7.1 10.8 3.5 1 6.3 3.15 ...
#  $ SS     : num  4.8 3 1 2.7 0 0 5.4 8.8 1.9 6 ...
#  $ FF_X   : num  5 5 4 6 6 8 6 4 5 6 ...
#  $ DDD_X  : num  290 300 310 320 240 240 310 320 320 10 ...
#  $ FF_AVG : num  2 3 2 2 4 3 3 2 3 2 ...
#  $ DDD_CAR: chr  "W" "NW" "W" "W" ...

# %%
unique(data$DDD_CAR)
# Out:
# [1] "W"  "NW" "SW" "N"  "S"  "NE" "E"  "SE"

# %%
# install.packages("fastDummies")

# %%
# Load paket fastDummies
library(fastDummies)

# Membuat dummy hanya untuk kolom DDD_CAR
data <- dummy_cols(data, select_columns = "DDD_CAR", remove_selected_columns = TRUE)

# Melihat hasil
head(data)
# Out:
# Warning message:
# "package 'fastDummies' was built under R version 4.4.2"
#   TN   TX   TAVG RH_AVG RR   SS  FF_X DDD_X FF_AVG DDD_CAR_E DDD_CAR_N
# 1 24.9 31.0 27.6 84      0.3 4.8 5    290   2      0         0
# 2 25.8 31.1 28.2 80      9.2 3.0 5    300   3      0         0
# 3 25.7 29.5 27.0 88      4.5 1.0 4    310   2      0         0
# 4 25.0 30.2 27.3 83      0.2 2.7 6    320   2      0         0
# 5 25.6 29.6 28.0 82      7.1 0.0 6    240   4      0         0
# 6 23.9 31.6 26.8 84     10.8 0.0 8    240   3      0         0
#   DDD_CAR_NE DDD_CAR_NW DDD_CAR_S DDD_CAR_SE DDD_CAR_SW DDD_CAR_W
# 1 0          0          0         0          0          1
# 2 0          1          0         0          0          0
# 3 0          0          0         0          0          1
# 4 0          0          0         0          0          1
# 5 0          0          0         0          0          1
# 6 0          0          0         0          1          0

# %% [markdown]
# 1. N - North (Utara)
# 2. S - South (Selatan)
# 3. E - East (Timur)
# 4. W - West (Barat)
# 5. NE - Northeast (Timur Laut)
# 6. NW - Northwest (Barat Laut)
# 7. SE - Southeast (Tenggara)
# 8. SW - Southwest (Barat Daya)

# %%
head(data)
# Out:
#   TN   TX   TAVG RH_AVG RR   SS  FF_X DDD_X FF_AVG DDD_CAR_E DDD_CAR_N
# 1 24.9 31.0 27.6 84      0.3 4.8 5    290   2      0         0
# 2 25.8 31.1 28.2 80      9.2 3.0 5    300   3      0         0
# 3 25.7 29.5 27.0 88      4.5 1.0 4    310   2      0         0
# 4 25.0 30.2 27.3 83      0.2 2.7 6    320   2      0         0
# 5 25.6 29.6 28.0 82      7.1 0.0 6    240   4      0         0
# 6 23.9 31.6 26.8 84     10.8 0.0 8    240   3      0         0
#   DDD_CAR_NE DDD_CAR_NW DDD_CAR_S DDD_CAR_SE DDD_CAR_SW DDD_CAR_W
# 1 0          0          0         0          0          1
# 2 0          1          0         0          0          0
# 3 0          0          0         0          0          1
# 4 0          0          0         0          0          1
# 5 0          0          0         0          0          1
# 6 0          0          0         0          1          0

# %%
library(nlme)
# Out:
# Warning message:
# "package 'nlme' was built under R version 4.4.2"

# %%
# Membangun model regresi linear berganda
model <- gls(TAVG ~ TN + TX + RH_AVG + RR + SS + FF_X + DDD_CAR_N + DDD_CAR_NE + DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SE + DDD_CAR_SW + DDD_CAR_W, data = data, method = "ML", weights = varIdent(form = ~ 1 | FF_X), correlation = corAR1())

# Melihat ringkasan model
summary(model)
# Out:
# Generalized least squares fit by maximum likelihood
#   Model: TAVG ~ TN + TX + RH_AVG + RR + SS + FF_X + DDD_CAR_N + DDD_CAR_NE +      DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SE + DDD_CAR_SW + DDD_CAR_W
#   Data: data
#        AIC      BIC    logLik
#   1905.538 2027.849 -929.7691
#
# Correlation Structure: AR(1)
#  Formula: ~1
#  Parameter estimate(s):
#       Phi
# 0.4515657
# Variance function:
#  Structure: Different standard deviations per stratum
#  Formula: ~1 | FF_X
#  Parameter estimates:
#         5         4         6         8         3         7         9         2
# 1.0000000 1.0482737 1.0140162 1.0191752 0.9517140 0.9390563 0.9127343 0.8683773
#
# Coefficients:
#                 Value Std.Error    t-value p-value
# (Intercept) 20.146656 0.7210283  27.941559  0.0000
# TN           0.223198 0.0143368  15.568171  0.0000
# TX           0.266523 0.0143821  18.531603  0.0000
# RH_AVG      -0.078728 0.0031194 -25.237824  0.0000
# RR          -0.003326 0.0045032  -0.738567  0.4603
# SS           0.001478 0.0040886   0.361574  0.7177
# FF_X        -0.010030 0.0090854  -1.104019  0.2698
# DDD_CAR_N   -0.023570 0.0541135  -0.435558  0.6632
# DDD_CAR_NE  -0.033248 0.0425430  -0.781511  0.4346
# DDD_CAR_NW   0.057792 0.0683081   0.846054  0.3977
# DDD_CAR_S   -0.133395 0.0439576  -3.034623  0.0024
# DDD_CAR_SE  -0.063255 0.1063782  -0.594622  0.5522
# DDD_CAR_SW  -0.189572 0.0444508  -4.264775  0.0000
# DDD_CAR_W   -0.104734 0.0534069  -1.961058  0.0501
#
#  Correlation:
#            (Intr) TN     TX     RH_AVG RR     SS     FF_X   DDD_CAR_N
# TN         -0.478
# TX         -0.830  0.016
# RH_AVG     -0.674 -0.018  0.526
# RR         -0.103  0.095  0.087 -0.032
# SS         -0.068 -0.065  0.043  0.096  0.138
# FF_X       -0.016 -0.055 -0.072  0.045  0.002  0.056
# DDD_CAR_N  -0.070  0.017  0.021  0.007 -0.004  0.038  0.166
# DDD_CAR_NE -0.043  0.016 -0.016  0.009 -0.003  0.018  0.098  0.503
# DDD_CAR_NW -0.055 -0.023  0.058 -0.018 -0.048  0.046  0.075  0.415
# DDD_CAR_S   0.021 -0.017 -0.059 -0.087 -0.039  0.026  0.218  0.572
# DDD_CAR_SE -0.002 -0.001 -0.011 -0.039 -0.039  0.017  0.100  0.222
# DDD_CAR_SW  0.000 -0.008 -0.046 -0.060 -0.042  0.031  0.162  0.588
# DDD_CAR_W  -0.008 -0.014 -0.029 -0.020 -0.073  0.034  0.063  0.484
#            DDD_CAR_NE DDD_CAR_NW DDD_CAR_S DDD_CAR_SE DDD_CAR_SW
# TN
# TX
# RH_AVG
# RR
# SS
# FF_X
# DDD_CAR_N
# DDD_CAR_NE
# DDD_CAR_NW  0.391
# DDD_CAR_S   0.618      0.453
# DDD_CAR_SE  0.243      0.198      0.297
# DDD_CAR_SW  0.605      0.502      0.706     0.290
# DDD_CAR_W   0.485      0.488      0.551     0.222      0.660
#
# Standardized residuals:
#         Min          Q1         Med          Q3         Max
# -3.92316041 -0.66851732  0.03370586  0.66811774  3.28124015
#
# Residual standard error: 0.4992499
# Degrees of freedom: 1507 total; 1493 residual

# %%
library(car)
# Menampilkan hasil VIF dalam format data frame
vif_df <- data.frame(VIF = vif(model))
print(vif_df)
# Out:
#                 VIF
# TN         1.020735
# TX         1.445958
# RH_AVG     1.454628
# RR         1.060659
# SS         1.043034
# FF_X       1.092109
# DDD_CAR_N  1.749354
# DDD_CAR_NE 1.864992
# DDD_CAR_NW 1.487102
# DDD_CAR_S  2.502654
# DDD_CAR_SE 1.120885
# DDD_CAR_SW 2.856718
# DDD_CAR_W  1.962040

# %% [markdown]
# # stepwise

# %%
library(MASS)

# %%
model.step <- stepAIC(model, direction = "both", trace = TRUE)
# Out:
# Start:  AIC=1905.54
# TAVG ~ TN + TX + RH_AVG + RR + SS + FF_X + DDD_CAR_N + DDD_CAR_NE +
#     DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SE + DDD_CAR_SW + DDD_CAR_W
#              Df    AIC
# - SS          1 1903.7
# - DDD_CAR_N   1 1903.7
# - DDD_CAR_SE  1 1903.9
# - RR          1 1904.1
# - DDD_CAR_NE  1 1904.2
# - DDD_CAR_NW  1 1904.2
# - FF_X        1 1904.6
# <none>          1905.5
# - DDD_CAR_W   1 1907.4
# - DDD_CAR_S   1 1912.7
# - DDD_CAR_SW  1 1921.5
# - TN          1 2078.5
# - TX          1 2190.0
# - RH_AVG      1 2391.3
#
# Step:  AIC=1903.67
# TAVG ~ TN + TX + RH_AVG + RR + FF_X + DDD_CAR_N + DDD_CAR_NE +
#     DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SE + DDD_CAR_SW + DDD_CAR_W
#
#              Df    AIC
# - DDD_CAR_N   1 1901.9
# - DDD_CAR_SE  1 1902.0
# - DDD_CAR_NE  1 1902.3
# - RR          1 1902.3
# - DDD_CAR_NW  1 1902.4
# - FF_X        1 1902.8
# <none>          1903.7
# + SS          1 1905.5
# - DDD_CAR_W   1 1905.6
# - DDD_CAR_S   1 1910.9
# - DDD_CAR_SW  1 1919.7
# - TN          1 2079.1
# - TX          1 2188.3
# - RH_AVG      1 2396.7
#
# Step:  AIC=1901.87
# TAVG ~ TN + TX + RH_AVG + RR + FF_X + DDD_CAR_NE + DDD_CAR_NW +
#     DDD_CAR_S + DDD_CAR_SE + DDD_CAR_SW + DDD_CAR_W
#
#              Df    AIC
# - DDD_CAR_SE  1 1900.1
# - DDD_CAR_NE  1 1900.3
# - RR          1 1900.5
# - FF_X        1 1900.9
# - DDD_CAR_NW  1 1901.1
# <none>          1901.9
# + DDD_CAR_N   1 1903.7
# + SS          1 1903.7
# - DDD_CAR_W   1 1903.9
# - DDD_CAR_S   1 1911.3
# - DDD_CAR_SW  1 1923.9
# - TN          1 2077.9
# - TX          1 2187.2
# - RH_AVG      1 2394.7
#
# Step:  AIC=1900.14
# TAVG ~ TN + TX + RH_AVG + RR + FF_X + DDD_CAR_NE + DDD_CAR_NW +
#     DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W
#
#              Df    AIC
# - DDD_CAR_NE  1 1898.5
# - RR          1 1898.8
# - FF_X        1 1899.1
# - DDD_CAR_NW  1 1899.5
# <none>          1900.1
# + DDD_CAR_SE  1 1901.9
# - DDD_CAR_W   1 1902.0
# + SS          1 1902.0
# + DDD_CAR_N   1 1902.0
# - DDD_CAR_S   1 1909.4
# - DDD_CAR_SW  1 1922.2
# - TN          1 2075.9
# - TX          1 2185.2
# - RH_AVG      1 2395.4
#
# Step:  AIC=1898.46
# TAVG ~ TN + TX + RH_AVG + RR + FF_X + DDD_CAR_NW + DDD_CAR_S +
#     DDD_CAR_SW + DDD_CAR_W
#
#              Df    AIC
# - RR          1 1897.1
# - FF_X        1 1897.4
# - DDD_CAR_NW  1 1898.3
# <none>          1898.5
# - DDD_CAR_W   1 1900.0
# + DDD_CAR_NE  1 1900.1
# + DDD_CAR_SE  1 1900.3
# + SS          1 1900.3
# + DDD_CAR_N   1 1900.5
# - DDD_CAR_S   1 1908.5
# - DDD_CAR_SW  1 1922.8
# - TN          1 2074.5
# - TX          1 2183.2
# - RH_AVG      1 2393.4
#
# Step:  AIC=1897.13
# TAVG ~ TN + TX + RH_AVG + FF_X + DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SW +
#     DDD_CAR_W
#
#              Df    AIC
# - FF_X        1 1896.1
# - DDD_CAR_NW  1 1896.8
# <none>          1897.1
# + RR          1 1898.5
# + DDD_CAR_NE  1 1898.8
# + SS          1 1898.9
# + DDD_CAR_SE  1 1898.9
# - DDD_CAR_W   1 1898.9
# + DDD_CAR_N   1 1899.1
# - DDD_CAR_S   1 1907.4
# - DDD_CAR_SW  1 1922.1
# - TN          1 2077.8
# - TX          1 2186.1
# - RH_AVG      1 2395.7
#
# Step:  AIC=1896.09
# TAVG ~ TN + TX + RH_AVG + DDD_CAR_NW + DDD_CAR_S + DDD_CAR_SW +
#     DDD_CAR_W
#
#              Df    AIC
# - DDD_CAR_NW  1 1895.8
# <none>          1896.1
# + FF_X        1 1897.1
# + RR          1 1897.4
# + DDD_CAR_NE  1 1897.8
# + SS          1 1897.8
# - DDD_CAR_W   1 1897.9
# + DDD_CAR_SE  1 1898.0
# + DDD_CAR_N   1 1898.1
# - DDD_CAR_S   1 1905.6
# - DDD_CAR_SW  1 1920.3
# - TN          1 2075.9
# - TX          1 2187.1
# - RH_AVG      1 2393.7
#
# Step:  AIC=1895.77
# TAVG ~ TN + TX + RH_AVG + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W
#
#              Df    AIC
# <none>          1895.8
# + DDD_CAR_NW  1 1896.1
# + FF_X        1 1896.8
# + DDD_CAR_NE  1 1897.0
# + RR          1 1897.2
# + DDD_CAR_SE  1 1897.5
# + SS          1 1897.5
# + DDD_CAR_N   1 1897.7
# - DDD_CAR_W   1 1899.8
# - DDD_CAR_S   1 1907.7
# - DDD_CAR_SW  1 1926.1
# - TN          1 2075.8
# - TX          1 2185.2
# - RH_AVG      1 2392.8

# %%
model2 <- gls(TAVG ~ TN + TX + RH_AVG + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W, data = data, method = "ML", weights = varIdent(form = ~ 1 | FF_X), correlation = corAR1())
summary(model2)
# Out:
# Generalized least squares fit by maximum likelihood
#   Model: TAVG ~ TN + TX + RH_AVG + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W
#   Data: data
#        AIC      BIC    logLik
#   1895.772 1980.858 -931.8858
#
# Correlation Structure: AR(1)
#  Formula: ~1
#  Parameter estimate(s):
#       Phi
# 0.4548533
# Variance function:
#  Structure: Different standard deviations per stratum
#  Formula: ~1 | FF_X
#  Parameter estimates:
#         5         4         6         8         3         7         9         2
# 1.0000000 1.0480427 1.0100617 1.0212709 0.9527148 0.9408247 0.9710991 0.7982175
#
# Coefficients:
#                 Value Std.Error    t-value p-value
# (Intercept) 20.200394 0.7134532  28.313552  0.0000
# TN           0.223683 0.0141819  15.772485  0.0000
# TX           0.263228 0.0142206  18.510357  0.0000
# RH_AVG      -0.078957 0.0030933 -25.525421  0.0000
# DDD_CAR_S   -0.113553 0.0303945  -3.735973  0.0002
# DDD_CAR_SW  -0.175769 0.0304824  -5.766235  0.0000
# DDD_CAR_W   -0.103570 0.0418614  -2.474123  0.0135
#
#  Correlation:
#            (Intr) TN     TX     RH_AVG DDD_CAR_S DDD_CAR_SW
# TN         -0.482
# TX         -0.832  0.009
# RH_AVG     -0.683 -0.005  0.539
# DDD_CAR_S   0.094 -0.022 -0.082 -0.133
# DDD_CAR_SW  0.070 -0.011 -0.079 -0.090  0.389
# DDD_CAR_W   0.038 -0.012 -0.057 -0.024  0.228     0.404
#
# Standardized residuals:
#         Min          Q1         Med          Q3         Max
# -3.95647038 -0.67740337  0.04162731  0.66239919  3.23221017
#
# Residual standard error: 0.500916
# Degrees of freedom: 1507 total; 1500 residual

# %% [markdown]
# ## Analisis residual
#
# Setelah mendapatkan model terbaik dengan melakukan pemilihan model menggunakan stepwise, selanjutnya akan dilakukan analisis residual untuk melihat apakah model regresi yang dipilih memenuhi asumsi-asumsi dari regresi linear atau tidak.

# %% [markdown]
# ### Asumsi normalitas
#
# Melihat histogram dan qqplot

# %%
install.packages("olsrr")
# Out:
# Installing package into 'C:/Users/Alif/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'olsrr' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Alif\AppData\Local\Temp\RtmpqWeg94\downloaded_packages

# %%
# Mengambil residual
residuals_model <- residuals(model2)

# Menghitung varians residual untuk setiap titik
fitted_values <- fitted(model2)
residual_variance <- diag(vcov(model2))

# Menghitung residual standar
residual_std <- residuals_model / sqrt(residual_variance)

# Menampilkan histogram untuk residual standar
hist(residual_std, main = "Histogram Residual Standar Model GLS", xlab = "Residual Standar", col = "lightblue", border = "black")
# Out:
# Warning message in residuals_model/sqrt(residual_variance):
# "longer object length is not a multiple of shorter object length"
# Plot with title "Histogram Residual Standar Model GLS"

# %%
# Q-Q plot
qqnorm(residuals_model)
qqline(residuals_model, col = "red")
# Out:
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# Uji hipotesis normalitas:
#
# -   H0: residual mengikuti distribusi normal
#
# -   H1: residual tidak mengikuti distribusi normal

# %%
# Mengambil residual
residuals_model <- residuals(model2)

# Uji normalitas
shapiro.test(residuals_model)  # Shapiro-Wilk
# Out:
# 	Shapiro-Wilk normality test
#
# data:  residuals_model
# W = 0.99877, p-value = 0.3813

# %% [markdown]
# ### Asumsi Homoskedastisitas

# %%
# Mengambil residual dari model GLS
residuals_model <- residuals(model2)

# Mengambil fitted values dari model GLS
fitted_values <- fitted(model2)

# Membuat plot residual vs fitted
plot(fitted_values, residuals_model,
     xlab = "Fitted Values",
     ylab = "Residuals",
     main = "Residuals vs Fitted for GLS Model")

# Menambahkan garis horizontal di 0
abline(h = 0, col = "red", lty = 2)
# Out:
# Plot with title "Residuals vs Fitted for GLS Model"

# %% [markdown]
# **uji Breusch-Pagan**
#
# Uji hipotesis variansi konstan:
#
# -   H0: variansi residual konstan (homoskedastisitas)
#
# -   H1: variansi residual tidak konstan (heteroskedastisitas)

# %%
# Install and load the lmtest package
# install.packages("lmtest")
library(lmtest)

# Mengambil residual dari model GLS
residuals_model <- residuals(model2)

# Mengambil fitted values dari model GLS
fitted_values <- fitted(model2)

# Membuat model linear dari residuals dan fitted values untuk uji Breusch-Pagan
bp_model <- lm(residuals_model ~ fitted_values)

# Melakukan uji Breusch-Pagan pada model linear tersebut
bptest(bp_model)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  bp_model
# BP = 1.6911, df = 1, p-value = 0.1935

# %%
install.packages("sandwich")
# Out:
# Installing package into 'C:/Users/Alif/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'sandwich' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Alif\AppData\Local\Temp\RtmpiYg9wv\downloaded_packages

# %%
library(sandwich)

# Melakukan White test pada model GLS
white_test <- bptest(model2, ~ fitted(model2) + I(fitted(model2)^2))
white_test
# Out:
# Warning message:
# "package 'sandwich' was built under R version 4.4.2"
# Error in as.data.frame.default(data): cannot coerce class 'c("glsStruct", "modelStruct")' to a data.frame
# Traceback:
#
# 1. bptest(model2, ~fitted(model2) + I(fitted(model2)^2))
# 2. model.matrix(terms(formula), model.frame(formula))
# 3. model.matrix.default(terms(formula), model.frame(formula))
# 4. model.frame(object, data, xlev = xlev)
# 5. model.frame.default(object, data, xlev = xlev)
# 6. as.data.frame(data)
# 7. as.data.frame.default(data)
# 8. stop(gettextf("cannot coerce class %s to a data.frame", sQuote(deparse(class(x))[1L])),
#  .     domain = NA)

# %% [markdown]
# ### Asumsi Independen
#
# **Dengan uji Durbin-Watson**
#
# Uji hipotesis variansi konstan:
#
# -   H0: residual independent
#
# -   H1: residual tidak independent

# %%
# Uji Durbin-Watson pada residual
dw_test <- dwtest(residuals_model ~ 1)

# Menampilkan hasil uji Durbin-Watson
dw_test
# Out:
# 	Durbin-Watson test
#
# data:  residuals_model ~ 1
# DW = 1.0885, p-value < 2.2e-16
# alternative hypothesis: true autocorrelation is greater than 0

# %% [markdown]
# p-value = 0 yang lebih kecil dari 0.05 menunjukkan bahwa kita menolak hipotesis nol (H0) dan menerima hipotesis alternatif (H1), yang berarti ada bukti kuat bahwa residual tidak independen dan terdapat autokorelasi dalam model regresi.

# %% [markdown]
# Karena residual model tidak homoskedastisitas dan residual tidak independen maka selanjutnya akan dilakukan transformasi terhadap variabel dependen atau TAVG.

# %%
# Uji Ljung-Box
ljung_box <- Box.test(residuals_model, lag = 1, type = "Ljung-Box")
print(ljung_box)
# Out:
# 	Box-Ljung test
#
# data:  residuals_model
# X-squared = 313.3, df = 1, p-value < 2.2e-16

# %% [markdown]
# ### Transformasi variabel TAVG

# %%
library(MASS)

# %%
bc <- boxcox(data$TAVG~1)
p <- bc$x[which.max(bc$y)]
p
# Out:
# [1] 2
# plot without title

# %% [markdown]
# **Model dengan Transformasi**

# %%
data$log_TAVG <- log(data$TAVG)
model2log <- gls(log_TAVG ~ TN + TX + RH_AVG + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W, data = data, method = "ML", weights = varIdent(form = ~ 1 | FF_X), correlation = corAR1())
summary(model2log)
# Out:
# Generalized least squares fit by maximum likelihood
#   Model: log_TAVG ~ TN + TX + RH_AVG + DDD_CAR_S + DDD_CAR_SW + DDD_CAR_W
#   Data: data
#         AIC       BIC   logLik
#   -8114.855 -8029.769 4073.427
#
# Correlation Structure: AR(1)
#  Formula: ~1
#  Parameter estimate(s):
#       Phi
# 0.4448927
# Variance function:
#  Structure: Different standard deviations per stratum
#  Formula: ~1 | FF_X
#  Parameter estimates:
#         5         4         6         8         3         7         9         2
# 1.0000000 1.0536639 1.0109547 1.0389764 0.9562340 0.9376559 1.0050732 0.7591487
#
# Coefficients:
#                  Value   Std.Error   t-value p-value
# (Intercept)  3.0477529 0.025744971 118.38246  0.0000
# TN           0.0081221 0.000511958  15.86478  0.0000
# TX           0.0095246 0.000513636  18.54349  0.0000
# RH_AVG      -0.0028422 0.000111712 -25.44244  0.0000
# DDD_CAR_S   -0.0040835 0.001100028  -3.71218  0.0002
# DDD_CAR_SW  -0.0064507 0.001101509  -5.85622  0.0000
# DDD_CAR_W   -0.0037880 0.001512094  -2.50511  0.0123
#
#  Correlation:
#            (Intr) TN     TX     RH_AVG DDD_CAR_S DDD_CAR_SW
# TN         -0.479
# TX         -0.833  0.006
# RH_AVG     -0.684 -0.008  0.542
# DDD_CAR_S   0.095 -0.022 -0.084 -0.133
# DDD_CAR_SW  0.071 -0.010 -0.081 -0.091  0.389
# DDD_CAR_W   0.037 -0.011 -0.057 -0.025  0.228     0.401
#
# Standardized residuals:
#         Min          Q1         Med          Q3         Max
# -4.01836980 -0.66824235  0.05377708  0.67342710  3.17789328
#
# Residual standard error: 0.01793254
# Degrees of freedom: 1507 total; 1500 residual

# %% [markdown]
# ### Asumsi Normalitas 2

# %%
# Mengambil residual
residuals_model_log <- residuals(model2log)

# Menghitung varians residual untuk setiap titik
fitted_values <- fitted(model2log)
residual_variance <- diag(vcov(model2log))

# Menghitung residual standar
residual_std <- residuals_model_log / sqrt(residual_variance)

# Menampilkan histogram untuk residual standar
hist(residual_std, main = "Histogram Residual Standar Model GLS", xlab = "Residual Standar", col = "lightblue", border = "black")
# Out:
# Warning message in residuals_model_log/sqrt(residual_variance):
# "longer object length is not a multiple of shorter object length"
# Plot with title "Histogram Residual Standar Model GLS"

# %%
# Q-Q plot
qqnorm(residuals_model_log)
qqline(residuals_model_log, col = "red")
# Out:
# Plot with title "Normal Q-Q Plot"

# %% [markdown]
# ### Asumsi Homoskedastisitas 2

# %%
# Mengambil fitted values dari model GLS
fitted_values <- fitted(model2)

# Membuat plot residual vs fitted
plot(fitted_values, residuals_model_log,
     xlab = "Fitted Values",
     ylab = "Residuals",
     main = "Residuals vs Fitted for GLS Model")

# Menambahkan garis horizontal di 0
abline(h = 0, col = "red", lty = 2)
# Out:
# Plot with title "Residuals vs Fitted for GLS Model"

# %%
# Install and load the lmtest package
# install.packages("lmtest")
library(lmtest)

# Mengambil fitted values dari model GLS
fitted_values <- fitted(model2)

# Membuat model linear dari residuals dan fitted values untuk uji Breusch-Pagan
bp_model <- lm(residuals_model_log ~ fitted_values)

# Melakukan uji Breusch-Pagan pada model linear tersebut
bptest(bp_model)
# Out:
# 	studentized Breusch-Pagan test
#
# data:  bp_model
# BP = 0.0072496, df = 1, p-value = 0.9321

# %%
# Uji Durbin-Watson pada residual
dw_test <- dwtest(residuals_model_log ~ 1)

# Tampilkan hasil uji
print(dw_test)
# Out:
# 	Durbin-Watson test
#
# data:  residuals_model_log ~ 1
# DW = 1.1086, p-value < 2.2e-16
# alternative hypothesis: true autocorrelation is greater than 0

# %%
install.packages("randtests")
# Out:
# Installing package into 'C:/Users/Alif/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'randtests' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Alif\AppData\Local\Temp\RtmpiYg9wv\downloaded_packages

# %%
library(randtests)
runs.test(residuals_model_log)
# Out:
# 	Runs Test
#
# data:  residuals_model_log
# statistic = -11.651, runs = 528, n1 = 753, n2 = 753, n = 1506, p-value
# < 2.2e-16
# alternative hypothesis: nonrandomness

# %%
# install.packages('nlme')
# Out:
# Installing package into 'C:/Users/Alif/AppData/Local/R/win-library/4.4'
# (as 'lib' is unspecified)
# package 'nlme' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Alif\AppData\Local\Temp\RtmpqWeg94\downloaded_packages
